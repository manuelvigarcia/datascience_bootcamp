# %% [markdown]
# # Multiple Linear Regression with Dummies - Exercise

# %% [markdown]
# You are given a real estate dataset.
#
# Real estate is one of those examples that every regression course goes through as it is extremely easy to understand and there is a (almost always) certain causal relationship to be found.
#
# The data is located in the file: 'real_estate_price_size_year_view.csv'.
#
# You are expected to create a multiple linear regression (similar to the one in the lecture), using the new data.
#
# In this exercise, the dependent variable is 'price', while the independent variables are 'size', 'year', and 'view'.
#
# #### Regarding the 'view' variable:
# There are two options: 'Sea view' and 'No sea view'. You are expected to create a dummy variable for view and include it in the regression
#
# Good luck!

# %% [markdown]
# ## Import the relevant libraries

# %%
import pandas as pd

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('real_estate_price_size_year_view.csv')

# %%
data.describe()
# Out:
#                price         size         year
# count     100.000000   100.000000   100.000000
# mean   292289.470160   853.024200  2012.600000
# std     77051.727525   297.941951     4.729021
# min    154282.128000   479.750000  2006.000000
# 25%    234280.148000   643.330000  2009.000000
# 50%    280590.716000   696.405000  2015.000000
# 75%    335723.696000  1029.322500  2018.000000
# max    500681.128000  1842.510000  2018.000000

# %%
data
# Out:
#          price     size  year         view
# 0   234314.144   643.09  2015  No sea view
# 1   228581.528   656.22  2009  No sea view
# 2   281626.336   487.29  2018     Sea view
# 3   401255.608  1504.75  2015  No sea view
# 4   458674.256  1275.46  2009     Sea view
# ..         ...      ...   ...          ...
# 95  252460.400   549.80  2009     Sea view
# 96  310522.592  1037.44  2009  No sea view
# 97  383635.568  1504.75  2006  No sea view
# 98  225145.248   648.29  2015  No sea view
# 99  274922.856   705.29  2006     Sea view
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Create a dummy variable for 'view'

# %%
data['view'] = data['view'].map({'Sea view':1,'No sea view':0})

# %%
data.describe()
# Out:
#                price         size         year        view
# count     100.000000   100.000000   100.000000  100.000000
# mean   292289.470160   853.024200  2012.600000    0.490000
# std     77051.727525   297.941951     4.729021    0.502418
# min    154282.128000   479.750000  2006.000000    0.000000
# 25%    234280.148000   643.330000  2009.000000    0.000000
# 50%    280590.716000   696.405000  2015.000000    0.000000
# 75%    335723.696000  1029.322500  2018.000000    1.000000
# max    500681.128000  1842.510000  2018.000000    1.000000

# %%
y = data['price']
x1 = data[['size', 'year', 'view']]

# %%
x = sm.add_constant(x1)

# %%
results = sm.OLS(y,x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.913
# Model:                            OLS   Adj. R-squared:                  0.910
# Method:                 Least Squares   F-statistic:                     335.2
# Date:                Mon, 22 Sep 2025   Prob (F-statistic):           1.02e-50
# Time:                        14:23:06   Log-Likelihood:                -1144.6
# No. Observations:                 100   AIC:                             2297.
# Df Residuals:                      96   BIC:                             2308.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.398e+06   9.94e+05     -5.431      0.000   -7.37e+06   -3.43e+06
# ...

# %%
#yhat_yes = 5454730 + 223.0316*data['size'] + 2718.9489 * data['year'] + 56730
#yhat_no = 5398000 + 223.0316*data['size'] + 2718.9489 * data['year']
yhat_yes = 5454730 + 223.0316*data['size']
yhat_no = 5398000 + 223.0316*data['size']
fig = plt.plot(data['size'],yhat_no, lw=2)
fig = plt.plot(data['size'],yhat_yes, lw=2)
#fig = plt.plot(data['year'],yhat_no, lw=2)
#fig = plt.plot(data['year'],yhat_yes, lw=2)

# %% [markdown]
# ## Create the regression

# %% [markdown]
# ### Declare the dependent and the independent variables

# %% [markdown]
# ### Regression
